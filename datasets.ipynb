# %%
import os

# Disable GPU usage:
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import jax
import distrax as dsx
import diffrax as dfx
import seaborn as sns

sns.set(style="whitegrid")

from simulated_sde_datasets import (
    StochasticLorenzAttractorDataset,
    StudentStochasticLorenzAttractorDataset,
    StochasticLotkaVolterraDataset,
    StudentStochasticLotkaVolterraDataset,
    OrnsteinUhlenbeckDiffusionDataset,
    StudentDiffusionDataset,
    SineForcingStudentDiffusionDataset,
    SineForcingOUDiffusionDataset,
    SquareForcingStudentDiffusionDataset,
    SquareForcingOUDiffusionDataset,
    GraphStudentDiffusionDataset,
    TriangleDropForcingOUDiffusionDataset,
    TriangleDropForcingStudentDiffusionDataset,
)

key = jax.random.PRNGKey(0)
# Out:
# 2024-02-23 12:51:38.392124: E external/xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# CUDA backend failed to initialize: FAILED_PRECONDITION: No visible GPU devices. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
dataset = OrnsteinUhlenbeckDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
dataset = StudentDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
    "initial_conditions_limits": [9, 11],
}
dataset = TriangleDropForcingOUDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
    "initial_conditions_limits": [9, 11],
}
dataset = TriangleDropForcingStudentDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
dataset = SineForcingOUDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
dataset = SineForcingStudentDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
dataset = SquareForcingOUDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "dt0": 0.01,
    "t1": 3,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
dataset = SquareForcingStudentDiffusionDataset(**dataset_specs)
data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "observation_model": dsx.Normal(0.0, 1e-2),
    "t1": 10.0,
    "dt0": 0.05,
    "brownian_motion_scale": 1e-1,
}
dataset = StochasticLotkaVolterraDataset(
    **dataset_specs,
)

data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "observation_model": dsx.Normal(0.0, 1e-2),
    "t1": 10.0,
    "dt0": 0.01,
    "brownian_motion_scale": 1e-2,
    "solver": dfx.ReversibleHeun(),
}
student_specs = {
    "theta": 1.0,
    "mu": 0.0,
    "delta": 1.0,
    "nu": 30.0,
}
dataset = StudentStochasticLotkaVolterraDataset(
    student_specs=student_specs, **dataset_specs
)

data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "t1": 2.0,
    "burn": 5,
    "initial_conditions_scale": 10.0,
    "brownian_motion_scale": 0.8,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
dataset = StochasticLorenzAttractorDataset(
    **dataset_specs,
)

data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset_specs = {
    "dataset_size": 16,
    "t1": 2.0,
    "burn": 5,
    "initial_conditions_scale": 10.0,
    "brownian_motion_scale": 0.8,
    "observation_model": dsx.Normal(0.0, 1e-2),
}
student_specs = {
    "theta": 1.0,
    "mu": 0.0,
    "delta": 1.0,
    "nu": 4.0,
}
dataset = StudentStochasticLorenzAttractorDataset(
    student_specs=student_specs,
    **dataset_specs,
)

data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()

# %%
dataset = GraphStudentDiffusionDataset(
    dataset_size=16,
    dt0=0.05,
    t1=20,
    burn=200,
    theta=1,
    nu=2,
    delta=1,
    solver=dfx.Heun(),
)

data_generation_key, key = jax.random.split(key)
dataset.setup(key=data_generation_key)
dataset.visualize_data()
